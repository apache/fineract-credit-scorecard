# %%
import json # will be needed for saving preprocessing details
import numpy as np # for data manipulation
import pandas as pd # for data manipulation
from sklearn.model_selection import train_test_split # will be used for data split
import requests

df = pd.read_csv('zoo/german_data.csv', index_col=0)
df = df.drop(columns = ['Saving accounts', 'Checking account'])

x_cols = [c for c in df.columns if c != 'Risk']

# set input matrix and target column
X = df[x_cols]
y = df['Risk']
# show first rows of data

df.head()
# Out:
#    Age     Sex  Job Housing  Credit amount  Duration              Purpose  \
# 0   67    male    2     own           1169         6             radio/TV
# 1   22  female    2     own           5951        48             radio/TV
# 2   49    male    1     own           2096        12            education
# 3   45    male    2    free           7882        42  furniture/equipment
# 4   53    male    2    free           4870        24                  car
#
#    Risk
# 0  good
# 1   bad
# 2  good
# 3  good
# 4   bad

# %%
# data split train / test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=1234)

# %%
for i in range(100):
    input_data = dict(X_test.iloc[i])
    target = y_test.iloc[i]
    r = requests.post("http://127.0.0.1:8000/api/v1/credit_scoring/predict?status=ab_testing", input_data)
    response = r.json()
    print(response)
    # provide feedback
    requests.put("http://127.0.0.1:8000/api/v1/mlrequests/{}".format(response["request_id"]), {"feedback": target})
# Out:
# {'probability': [0], 'label': 'bad', 'status': 'OK', 'request_id': 101}
# {'probability': [0], 'label': 'bad', 'status': 'OK', 'request_id': 102}
# {'probability': [0], 'label': 'bad', 'status': 'OK', 'request_id': 103}
# {'probability': [0], 'label': 'bad', 'status': 'OK', 'request_id': 104}
# {'probability': [0], 'label': 'bad', 'status': 'OK', 'request_id': 105}
# {'probability': [0], 'label': 'bad', 'status': 'OK', 'request_id': 106}
# {'probability': [0], 'label': 'bad', 'status': 'OK', 'request_id': 107}
# {'probability': [0], 'label': 'bad', 'status': 'OK', 'request_id': 108}
# {'probability': [0], 'label': 'bad', 'status': 'OK', 'request_id': 109}
# {'probability': [0], 'label': 'bad', 'status': 'OK', 'request_id': 110}
# {'probability': [0], 'label': 'bad', 'status': 'OK', 'request_id': 111}
# {'probability': [0], 'label': 'bad', 'status': 'OK', 'request_id': 112}
# {'probability': [0], 'label': 'bad', 'status': 'OK', 'request_id': 113}
# ...
